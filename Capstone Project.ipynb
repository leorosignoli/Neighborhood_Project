# %% [markdown]
# # Downloading libraries
# Here i'll be getting all the libraries i'm going to use in this project.

# %%
#Importing libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from pandas.io.html import read_html

# %%
print ('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# # Getting the data
# In the following steps i get the table from the wikipedia website and turn it into a pandas Dataframe.

# %%
#getting the table

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

table = read_html(url,  attrs={"class":"wikitable"})

# %%
#Transforming the table into a dataframe

df = pd.DataFrame(table[0])
df.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor
# 7      M7A  Downtown Toronto      Queen's Park
# 8      M8A      Not assigned      Not assigned
# 9      M9A      Queen's Park      Not assigned

# %% [markdown]
# # Data normalization
# Here I normalize the dataset before beginning to use it.

# %%
#dropping all 'Not assigned' Boroughs

df = df.set_index('Borough')
df = df.drop('Not assigned', axis = 0)
df = df.reset_index(drop=False)
df.head(10)
# Out:
#             Borough Postcode     Neighbourhood
# 0        North York      M3A         Parkwoods
# 1        North York      M4A  Victoria Village
# 2  Downtown Toronto      M5A      Harbourfront
# 3        North York      M6A  Lawrence Heights
# 4        North York      M6A    Lawrence Manor
# 5  Downtown Toronto      M7A      Queen's Park
# 6      Queen's Park      M9A      Not assigned
# 7       Scarborough      M1B             Rouge
# 8       Scarborough      M1B           Malvern
# 9        North York      M3B   Don Mills North

# %%
# Combining rows with the same postal code
df.set_index(['Postcode'],inplace=True)
df = df.groupby(level='Postcode', sort=False).agg( ', '.join)
df = df.reset_index(drop=False)
df.head()
# Out:
#   Postcode                 Borough                     Neighbourhood
# 0      M3A              North York                         Parkwoods
# 1      M4A              North York                  Victoria Village
# 2      M5A        Downtown Toronto                      Harbourfront
# 3      M6A  North York, North York  Lawrence Heights, Lawrence Manor
# 4      M7A        Downtown Toronto                      Queen's Park

# %%
# Locating all 'not assigned' Neighbourhoods and replacing it with their respective boroughs

for index, row in df.iterrows():
    if df.loc[index, 'Neighbourhood'] =='x':
        df.loc[index,'Neighbourhood'] = df.loc[index,'Borough']
df
# Out:
#     Postcode                                            Borough  \
# 0        M3A                                         North York
# 1        M4A                                         North York
# 2        M5A                                   Downtown Toronto
# 3        M6A                             North York, North York
# 4        M7A                                   Downtown Toronto
# 5        M9A                                       Queen's Park
# 6        M1B                           Scarborough, Scarborough
# 7        M3B                                         North York
# 8        M4B                               East York, East York
# 9        M5B                 Downtown Toronto, Downtown Toronto
# 10       M6B                                         North York
# 11       M9B  Etobicoke, Etobicoke, Etobicoke, Etobicoke, Et...
# 12       M1C              Scarborough, Scarborough, Scarborough
# 13       M3C                             North York, North York
# 14       M4C                                          East York
# 15       M5C                                   Downtown Toronto
# 16       M6C                                               York
# 17       M9C         Etobicoke, Etobicoke, Etobicoke, Etobicoke
# 18       M1E              Scarborough, Scarborough, Scarborough
# 19       M4E                                       East Toronto
# 20       M5E                                   Downtown Toronto
# 21       M6E                                               York
# 22       M1G                                        Scarborough
# 23       M4G                                          East York
# 24       M5G                                   Downtown Toronto
# 25       M6G                                   Downtown Toronto
# 26       M1H                                        Scarborough
# 27       M2H                                         North York
# 28       M3H                 North York, North York, North York
# 29       M4H                                          East York
# ..       ...                                                ...
# 73       M4R                                    Central Toronto
# 74       M5R  Central Toronto, Central Toronto, Central Toronto
# 75       M6R                         West Toronto, West Toronto
# 76       M7R                                        Mississauga
# 77       M9R         Etobicoke, Etobicoke, Etobicoke, Etobicoke
# 78       M1S                                        Scarborough
# 79       M4S                                    Central Toronto
# 80       M5S                 Downtown Toronto, Downtown Toronto
# 81       M6S                         West Toronto, West Toronto
# 82       M1T              Scarborough, Scarborough, Scarborough
# 83       M4T                   Central Toronto, Central Toronto
# 84       M5T  Downtown Toronto, Downtown Toronto, Downtown T...
# 85       M1V  Scarborough, Scarborough, Scarborough, Scarbor...
# 86       M4V  Central Toronto, Central Toronto, Central Toro...
# 87       M5V  Downtown Toronto, Downtown Toronto, Downtown T...
# 88       M8V                    Etobicoke, Etobicoke, Etobicoke
# 89       M9V  Etobicoke, Etobicoke, Etobicoke, Etobicoke, Et...
# 90       M1W                                        Scarborough
# 91       M4W                                   Downtown Toronto
# 92       M5W                                   Downtown Toronto
# 93       M8W                               Etobicoke, Etobicoke
# 94       M9W                                          Etobicoke
# 95       M1X                                        Scarborough
# 96       M4X                 Downtown Toronto, Downtown Toronto
# 97       M5X                 Downtown Toronto, Downtown Toronto
# 98       M8X                    Etobicoke, Etobicoke, Etobicoke
# 99       M4Y                                   Downtown Toronto
# 100      M7Y                                       East Toronto
# 101      M8Y  Etobicoke, Etobicoke, Etobicoke, Etobicoke, Et...
# 102      M8Z  Etobicoke, Etobicoke, Etobicoke, Etobicoke, Et...
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                     Lawrence Heights, Lawrence Manor
# 4                                         Queen's Park
# 5                                         Queen's Park
# 6                                       Rouge, Malvern
# 7                                      Don Mills North
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 10                                           Glencairn
# 11   Cloverdale, Islington, Martin Grove, Princess ...
# 12              Highland Creek, Rouge Hill, Port Union
# 13                    Flemingdon Park, Don Mills South
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 83                         Moore Park, Summerhill East
# 84           Chinatown, Grange Park, Kensington Market
# 85   Agincourt North, L'Amoreaux East, Milliken, St...
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 90                                     L'Amoreaux West
# 91                                            Rosedale
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                              Alderwood, Long Branch
# 94                                           Northwest
# 95                                         Upper Rouge
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)
